# %% [markdown]
# # Step 4 - Model and evaluation

# %% [markdown]
# ## A. Import thư viện

# %%
# 1. Import library
import lib.step1ml_utilis_summaryPre_processing as pre
import lib.step2ml_utils_feature_selection as fea
import lib.step3ml_utils_model_design_testing_regression as reg
import lib.step4ml_utils_model_design_testing_explainability as exp
import lib.step5ml_utils_model_design_testing_visualize_models as vis
import lib.step6ml_utils_model_design_testing_geospatial_analysis as geo
import lib.step9ml_Text_Kmeans_Clustering as clu
#import lib.step11ml_utilis_model_design_time_series as clu
import matplotlib
import matplotlib_inline
# %matplotlib inline


import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# # B. Model

# %% [markdown]
# ### 1.0. Upload dữ liệu

# %%
import pandas as pd
dir_file = "data/avocado_model.csv"
df = pd.read_csv(dir_file)
df.head()
# Out:
#    Unnamed: 0    fea_date  fea_average_price  fea_total_Volume  fea_item_4046  \
# 0           1  2015-12-27               1.33          64236.62        1036.74
# 1           2  2015-12-20               1.35          54876.98         674.28
# 2           3  2015-12-13               0.93         118220.22         794.70
# 3           4  2015-12-06               1.08          78992.15        1132.00
# 4           5  2015-11-29               1.28          51039.60         941.48
#
#    fea_item_4225  fea_item_4770  fea_total_Bags  fea_small_bags  \
# 0       54454.85          48.16         8696.87         8603.62
# 1       44638.81          58.33         9505.56         9408.07
# 2      109149.67         130.50         8145.35         8042.21
# 3       71976.41          72.58         5811.16         5677.40
# 4       43838.39          75.78         6183.95         5986.26
#
#    fea_large_bags  ...  Item_4046  Item_4225  Item_4770  Total_Bags  \
# 0           93.25  ...    1036.74   54454.85      48.16     8696.87
# 1           97.49  ...     674.28   44638.81      58.33     9505.56
# 2          103.14  ...     794.70  109149.67     130.50     8145.35
# 3          133.76  ...    1132.00   71976.41      72.58     5811.16
# 4          197.69  ...     941.48   43838.39      75.78     6183.95
#
#    Small_Bags  Large_Bags  XLarge_Bags          type  year  region
# 0     8603.62       93.25         0.00  conventional  2015  Albany
# 1     9408.07       97.49         0.00  conventional  2015  Albany
# 2     8042.21      103.14         0.00  conventional  2015  Albany
# 3     5677.40      133.76         0.00  conventional  2015  Albany
# 4     5986.26      197.69         0.00  conventional  2015  Albany
#
# [5 rows x 95 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18249 entries, 0 to 18248
# Data columns (total 95 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Unnamed: 0                      18249 non-null  int64
#  1   fea_date                        18249 non-null  object
#  2   fea_average_price               18249 non-null  float64
#  3   fea_total_Volume                18249 non-null  float64
#  4   fea_item_4046                   18249 non-null  float64
#  5   fea_item_4225                   18249 non-null  float64
#  6   fea_item_4770                   18249 non-null  float64
#  7   fea_total_Bags                  18249 non-null  float64
#  8   fea_small_bags                  18249 non-null  float64
#  9   fea_large_bags                  18249 non-null  float64
#  10  fea_xlarge_bags                 18249 non-null  float64
#  11  total_volumn_item               18249 non-null  float64
#  12  fea_year_                       18249 non-null  int64
#  13  fea_month                       18249 non-null  int64
#  14  fea_day                         18249 non-null  int64
#  15  fea_weekofyear                  18249 non-null  int64
#  16  fea_daily                       18249 non-null  int64
#  17  fea_id                          18249 non-null  int64
#  18  fea_type_organic                18249 non-null  int64
#  19  fea_region_Atlanta              18249 non-null  int64
#  20  fea_region_BaltimoreWashington  18249 non-null  int64
#  21  fea_region_Boise                18249 non-null  int64
#  22  fea_region_Boston               18249 non-null  int64
#  23  fea_region_BuffaloRochester     18249 non-null  int64
#  24  fea_region_California           18249 non-null  int64
#  25  fea_region_Charlotte            18249 non-null  int64
#  26  fea_region_Chicago              18249 non-null  int64
#  27  fea_region_CincinnatiDayton     18249 non-null  int64
#  28  fea_region_Columbus             18249 non-null  int64
#  29  fea_region_DallasFtWorth        18249 non-null  int64
#  30  fea_region_Denver               18249 non-null  int64
#  31  fea_region_Detroit              18249 non-null  int64
#  32  fea_region_GrandRapids          18249 non-null  int64
#  33  fea_region_GreatLakes           18249 non-null  int64
#  34  fea_region_HarrisburgScranton   18249 non-null  int64
#  35  fea_region_HartfordSpringfield  18249 non-null  int64
#  36  fea_region_Houston              18249 non-null  int64
#  37  fea_region_Indianapolis         18249 non-null  int64
#  38  fea_region_Jacksonville         18249 non-null  int64
#  39  fea_region_LasVegas             18249 non-null  int64
#  40  fea_region_LosAngeles           18249 non-null  int64
#  41  fea_region_Louisville           18249 non-null  int64
#  42  fea_region_MiamiFtLauderdale    18249 non-null  int64
#  43  fea_region_Midsouth             18249 non-null  int64
#  44  fea_region_Nashville            18249 non-null  int64
#  45  fea_region_NewOrleansMobile     18249 non-null  int64
#  46  fea_region_NewYork              18249 non-null  int64
#  47  fea_region_Northeast            18249 non-null  int64
#  48  fea_region_NorthernNewEngland   18249 non-null  int64
#  49  fea_region_Orlando              18249 non-null  int64
#  50  fea_region_Philadelphia         18249 non-null  int64
#  51  fea_region_PhoenixTucson        18249 non-null  int64
#  52  fea_region_Pittsburgh           18249 non-null  int64
#  53  fea_region_Plains               18249 non-null  int64
#  54  fea_region_Portland             18249 non-null  int64
#  55  fea_region_RaleighGreensboro    18249 non-null  int64
#  56  fea_region_RichmondNorfolk      18249 non-null  int64
#  57  fea_region_Roanoke              18249 non-null  int64
#  58  fea_region_Sacramento           18249 non-null  int64
#  59  fea_region_SanDiego             18249 non-null  int64
#  60  fea_region_SanFrancisco         18249 non-null  int64
#  61  fea_region_Seattle              18249 non-null  int64
#  62  fea_region_SouthCarolina        18249 non-null  int64
#  63  fea_region_SouthCentral         18249 non-null  int64
#  64  fea_region_Southeast            18249 non-null  int64
#  65  fea_region_Spokane              18249 non-null  int64
#  66  fea_region_StLouis              18249 non-null  int64
#  67  fea_region_Syracuse             18249 non-null  int64
#  68  fea_region_Tampa                18249 non-null  int64
#  69  fea_region_TotalUS              18249 non-null  int64
#  70  fea_region_West                 18249 non-null  int64
#  71  fea_region_WestTexNewMexico     18249 non-null  int64
#  72  fea_total_Volume_scaler         18249 non-null  float64
#  73  fea_item_4046_scaler            18249 non-null  float64
#  74  fea_item_4225_scaler            18249 non-null  float64
#  75  fea_item_4770_scaler            18249 non-null  float64
#  76  fea_total_Bags_scaler           18249 non-null  float64
#  77  fea_small_bags_scaler           18249 non-null  float64
#  78  fea_large_bags_scaler           18249 non-null  float64
#  79  fea_xlarge_bags_scaler          18249 non-null  float64
#  80  total_volumn_item_scaler        18249 non-null  float64
#  81  Id                              18249 non-null  int64
#  82  Date                            18249 non-null  object
#  83  AveragePrice                    18249 non-null  float64
#  84  Total_Volume                    18249 non-null  float64
#  85  Item_4046                       18249 non-null  float64
#  86  Item_4225                       18249 non-null  float64
#  87  Item_4770                       18249 non-null  float64
#  88  Total_Bags                      18249 non-null  float64
#  89  Small_Bags                      18249 non-null  float64
#  90  Large_Bags                      18249 non-null  float64
#  91  XLarge_Bags                     18249 non-null  float64
#  92  type                            18249 non-null  object
#  93  year                            18249 non-null  int64
#  94  region                          18249 non-null  object
# dtypes: float64(28), int64(63), object(4)
# memory usage: 13.2+ MB

# %% [markdown]
# ### 1.1. Chọn lst_k_best

# %%
#lst_k_best_option1 = ['fea_type_organic','fea_total_Volume', 'fea_region_LosAngeles', 'fea_item_4046', 'fea_region_Houston','fea_region_PhoenixTucson', 'fea_region_Denver', 
#              'fea_region_DallasFtWorth','fea_region_CincinnatiDayton', 'fea_region_Roanoke', 'fea_region_SouthCentral', 'fea_region_Nashville', 
#              'fea_large_bags', 'fea_month', 'fea_item_4225', 'fea_item_4770', 'fea_total_Bags','fea_small_bags','total_volumn_item' ]
lst_k_best_option1 = ['fea_average_price','fea_type_organic', 'fea_large_bags', 'fea_item_4046', 'fea_item_4225', 'fea_small_bags', 'fea_total_Bags', 'fea_item_4770', 'fea_month', 
    'total_volumn_item', 'fea_total_Volume','fea_xlarge_bags' ]

lst_k_best_option2_scaler = ['fea_average_price','fea_type_organic', 'fea_month', 'fea_total_Volume_scaler', 'fea_item_4046_scaler','fea_item_4225_scaler', 'fea_item_4770_scaler', 'fea_total_Bags_scaler','fea_small_bags_scaler', 
              'fea_large_bags_scaler','fea_xlarge_bags_scaler', 'total_volumn_item_scaler']

# %%
data_model_k_best_option1 = df[lst_k_best_option1]
data_model_k_best_option2_scaler = df[lst_k_best_option2_scaler]

# %%
data_model_k_best_option1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18249 entries, 0 to 18248
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   fea_average_price  18249 non-null  float64
#  1   fea_type_organic   18249 non-null  int64
#  2   fea_large_bags     18249 non-null  float64
#  3   fea_item_4046      18249 non-null  float64
#  4   fea_item_4225      18249 non-null  float64
#  5   fea_small_bags     18249 non-null  float64
#  6   fea_total_Bags     18249 non-null  float64
#  7   fea_item_4770      18249 non-null  float64
#  8   fea_month          18249 non-null  int64
#  9   total_volumn_item  18249 non-null  float64
#  10  fea_total_Volume   18249 non-null  float64
#  11  fea_xlarge_bags    18249 non-null  float64
# dtypes: float64(10), int64(2)
# memory usage: 1.7 MB

# %%
data_model_k_best_option2_scaler.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18249 entries, 0 to 18248
# Data columns (total 12 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   fea_average_price         18249 non-null  float64
#  1   fea_type_organic          18249 non-null  int64
#  2   fea_month                 18249 non-null  int64
#  3   fea_total_Volume_scaler   18249 non-null  float64
#  4   fea_item_4046_scaler      18249 non-null  float64
#  5   fea_item_4225_scaler      18249 non-null  float64
#  6   fea_item_4770_scaler      18249 non-null  float64
#  7   fea_total_Bags_scaler     18249 non-null  float64
#  8   fea_small_bags_scaler     18249 non-null  float64
#  9   fea_large_bags_scaler     18249 non-null  float64
#  10  fea_xlarge_bags_scaler    18249 non-null  float64
#  11  total_volumn_item_scaler  18249 non-null  float64
# dtypes: float64(10), int64(2)
# memory usage: 1.7 MB

# %% [markdown]
# ### 1.2. Tách 2 bộ dữ liệu type
# - conventional
# - organic

# %%
data_conventional = pre.filter_dataframe(df=df, feature_name='type', name_type='conventional')
# Out:
# close

# %%
data_organic = pre.filter_dataframe(df=df, feature_name='type', name_type='organic')
# Out:
# close

# %%
data_model_k_best_conventional = data_conventional[lst_k_best_option1]
data_model_k_best_conventional_scaler = data_conventional[lst_k_best_option2_scaler]

# %%
data_model_k_best_organic = data_organic[lst_k_best_option1]
data_model_k_best_organic_scaler = data_organic[lst_k_best_option2_scaler]

# %% [markdown]
# ### 1.3. Hàm Kỹ thuật khác và biểu đồ
# 1. Hàm thực hiện cross valiation
# 2. Hàm thực hiện K-Folds
# 3. Hàm GridSearchCV
# 4. Hàm RandomSearch
# 5. Hàm Select Model

# %% [markdown]
# ## B1. Chọn Model - check nmodel
# - original
# - scaler

# %%
reg.check_model(df=data_model_k_best_conventional, y="fea_average_price", choose="select")
# Out:
#                    model_name  score_train_mean  score_test_mean  abs|score|  \
# 0            LinearRegression              0.13             0.13        0.00
# 1            LinearRegression              0.13             0.13        0.01
# 2            LinearRegression              0.13             0.12        0.01
# 3            LinearRegression              0.13             0.12        0.01
# 4            LinearRegression              0.13             0.12        0.01
# 5         KNeighborsRegressor              0.74             0.55        0.19
# 6         KNeighborsRegressor              0.74             0.56        0.18
# 7         KNeighborsRegressor              0.74             0.57        0.17
# 8         KNeighborsRegressor              0.74             0.57        0.17
# 9         KNeighborsRegressor              0.74             0.58        0.16
# 10                        SVR              0.23             0.22        0.00
# 11                        SVR              0.23             0.22        0.00
# 12                        SVR              0.23             0.22        0.01
# 13                        SVR              0.23             0.22        0.01
# 14                        SVR              0.23             0.22        0.01
# 15      RandomForestRegressor              0.97             0.76        0.21
# 16      RandomForestRegressor              0.97             0.77        0.20
# 17      RandomForestRegressor              0.97             0.77        0.20
# 18      RandomForestRegressor              0.97             0.76        0.20
# 19      RandomForestRegressor              0.97             0.76        0.21
# 20  GradientBoostingRegressor              0.59             0.55        0.04
# 21  GradientBoostingRegressor              0.59             0.54        0.05
# 22  GradientBoostingRegressor              0.59             0.54        0.05
# 23  GradientBoostingRegressor              0.59             0.54        0.05
# 24  GradientBoostingRegressor              0.59             0.54        0.05
# 25               XGBRegressor              0.95             0.73        0.22
# 26               XGBRegressor              0.95             0.73        0.22
# 27               XGBRegressor              0.95             0.73        0.22
# 28               XGBRegressor              0.95             0.72        0.22
# 29               XGBRegressor              0.95             0.73        0.22
# 30              LGBMRegressor              0.45             0.40        0.05
# 31              LGBMRegressor              0.45             0.40        0.05
# 32              LGBMRegressor              0.45             0.40        0.04
# 33              LGBMRegressor              0.44             0.41        0.04
# 34              LGBMRegressor              0.44             0.41        0.03
#
#     time_mean  mean_squared_error_train  mean_squared_error_test
# 0        6.00                      0.25                     0.24
# 1        5.00                      0.25                     0.24
# 2        4.67                      0.25                     0.24
# 3        4.50                      0.25                     0.24
# 4        5.00                      0.25                     0.24
# 5       20.90                      0.13                     0.17
# 6       19.90                      0.14                     0.17
# 7       18.93                      0.13                     0.17
# 8       18.45                      0.14                     0.17
# 9       19.14                      0.14                     0.17
# 10     375.80                      0.23                     0.23
# 11     461.85                      0.23                     0.23
# 12     533.43                      0.23                     0.23
# 13     563.53                      0.23                     0.23
# 14     545.26                      0.23                     0.23
# 15     251.70                      0.05                     0.13
# 16     450.80                      0.05                     0.13
# 17     564.20                      0.05                     0.13
# 18     652.20                      0.05                     0.13
# 19     643.26                      0.05                     0.13
# 20     127.80                      0.17                     0.18
# 21     124.90                      0.17                     0.18
# 22     161.60                      0.17                     0.18
# 23     366.18                      0.17                     0.18
# 24     293.86                      0.17                     0.18
# 25     271.60                      0.06                     0.14
# 26     349.40                      0.06                     0.14
# 27     378.67                      0.06                     0.14
# 28     317.50                      0.06                     0.14
# 29     285.58                      0.06                     0.14
# 30     110.70                      0.20                     0.20
# 31      94.75                      0.20                     0.20
# 32      90.43                      0.20                     0.20
# 33      88.03                      0.20                     0.20
# 34     100.04                      0.20                     0.20

# %%
reg.check_model(df=data_model_k_best_option2_scaler, y="fea_average_price", choose="select")
# Out:
#                    model_name  score_train_mean  score_test_mean  abs|score|  \
# 0            LinearRegression              0.42             0.43        0.01
# 1            LinearRegression              0.42             0.43        0.01
# 2            LinearRegression              0.42             0.43        0.01
# 3            LinearRegression              0.42             0.43        0.01
# 4            LinearRegression              0.42             0.43        0.01
# 5         KNeighborsRegressor              0.78             0.65        0.13
# 6         KNeighborsRegressor              0.77             0.66        0.12
# 7         KNeighborsRegressor              0.78             0.65        0.12
# 8         KNeighborsRegressor              0.78             0.65        0.13
# 9         KNeighborsRegressor              0.78             0.65        0.13
# 10                        SVR              0.37             0.36        0.01
# 11                        SVR              0.37             0.37        0.01
# 12                        SVR              0.37             0.37        0.00
# 13                        SVR              0.37             0.37        0.00
# 14                        SVR              0.37             0.37        0.00
# 15      RandomForestRegressor              0.97             0.81        0.16
# 16      RandomForestRegressor              0.97             0.81        0.17
# 17      RandomForestRegressor              0.97             0.81        0.17
# 18      RandomForestRegressor              0.97             0.81        0.17
# 19      RandomForestRegressor              0.97             0.81        0.17
# 20  GradientBoostingRegressor              0.68             0.65        0.03
# 21  GradientBoostingRegressor              0.67             0.65        0.02
# 22  GradientBoostingRegressor              0.67             0.65        0.02
# 23  GradientBoostingRegressor              0.67             0.65        0.02
# 24  GradientBoostingRegressor              0.67             0.65        0.02
# 25               XGBRegressor              0.91             0.77        0.13
# 26               XGBRegressor              0.91             0.78        0.13
# 27               XGBRegressor              0.91             0.77        0.14
# 28               XGBRegressor              0.91             0.77        0.14
# 29               XGBRegressor              0.91             0.77        0.14
# 30              LGBMRegressor              0.54             0.53        0.01
# 31              LGBMRegressor              0.54             0.53        0.01
# 32              LGBMRegressor              0.54             0.53        0.01
# 33              LGBMRegressor              0.54             0.53        0.02
# 34              LGBMRegressor              0.54             0.53        0.01
#
#     time_mean  mean_squared_error_train  mean_squared_error_test
# 0        7.00                      0.31                     0.30
# 1        8.00                      0.31                     0.30
# 2        9.00                      0.31                     0.30
# 3        9.25                      0.31                     0.30
# 4        9.40                      0.31                     0.31
# 5      171.50                      0.19                     0.24
# 6      171.50                      0.19                     0.24
# 7      188.80                      0.19                     0.24
# 8      194.95                      0.19                     0.24
# 9      190.06                      0.19                     0.24
# 10      56.00                      0.32                     0.32
# 11     359.90                      0.32                     0.32
# 12     562.50                      0.32                     0.32
# 13     437.25                      0.32                     0.32
# 14     484.24                      0.32                     0.32
# 15     533.80                      0.07                     0.18
# 16     268.00                      0.07                     0.18
# 17     419.13                      0.07                     0.18
# 18     328.50                      0.07                     0.18
# 19     399.54                      0.07                     0.18
# 20     176.00                      0.23                     0.24
# 21     496.65                      0.23                     0.24
# 22     650.63                      0.23                     0.24
# 23     704.28                      0.23                     0.24
# 24     759.08                      0.23                     0.24
# 25     374.70                      0.12                     0.19
# 26     203.65                      0.12                     0.19
# 27     216.30                      0.12                     0.19
# 28     267.85                      0.12                     0.19
# 29     239.64                      0.12                     0.19
# 30      86.80                      0.27                     0.27
# 31      88.30                      0.27                     0.28
# 32     102.40                      0.27                     0.28
# 33     107.22                      0.27                     0.28
# 34     102.54                      0.27                     0.28

# %% [markdown]
# ## B2. Chọn model - check model - theo type
# - conventional
# - organic

# %%
reg.check_model(df=data_model_k_best_conventional, y="fea_average_price", choose="select")
# Out:
#                    model_name  score_train_mean  score_test_mean  abs|score|  \
# 0            LinearRegression              0.13             0.13        0.00
# 1            LinearRegression              0.13             0.13        0.01
# 2            LinearRegression              0.13             0.13        0.01
# 3            LinearRegression              0.13             0.13        0.01
# 4            LinearRegression              0.13             0.13        0.01
# 5         KNeighborsRegressor              0.73             0.59        0.14
# 6         KNeighborsRegressor              0.73             0.61        0.12
# 7         KNeighborsRegressor              0.73             0.61        0.12
# 8         KNeighborsRegressor              0.73             0.60        0.13
# 9         KNeighborsRegressor              0.73             0.60        0.13
# 10                        SVR              0.22             0.23        0.01
# 11                        SVR              0.22             0.23        0.01
# 12                        SVR              0.22             0.23        0.02
# 13                        SVR              0.22             0.23        0.02
# 14                        SVR              0.22             0.23        0.02
# 15      RandomForestRegressor              0.97             0.76        0.21
# 16      RandomForestRegressor              0.97             0.76        0.21
# 17      RandomForestRegressor              0.97             0.76        0.21
# 18      RandomForestRegressor              0.97             0.76        0.21
# 19      RandomForestRegressor              0.97             0.76        0.21
# 20  GradientBoostingRegressor              0.60             0.55        0.05
# 21  GradientBoostingRegressor              0.59             0.55        0.05
# 22  GradientBoostingRegressor              0.59             0.54        0.05
# 23  GradientBoostingRegressor              0.60             0.54        0.06
# 24  GradientBoostingRegressor              0.60             0.54        0.06
# 25               XGBRegressor              0.95             0.73        0.22
# 26               XGBRegressor              0.95             0.73        0.22
# 27               XGBRegressor              0.95             0.72        0.23
# 28               XGBRegressor              0.95             0.72        0.23
# 29               XGBRegressor              0.95             0.72        0.23
# 30              LGBMRegressor              0.45             0.41        0.04
# 31              LGBMRegressor              0.45             0.41        0.04
# 32              LGBMRegressor              0.45             0.41        0.03
# 33              LGBMRegressor              0.45             0.41        0.04
# 34              LGBMRegressor              0.45             0.41        0.03
#
#     time_mean  mean_squared_error_train  mean_squared_error_test
# 0        6.00                      0.24                     0.25
# 1        5.50                      0.24                     0.25
# 2        5.00                      0.24                     0.25
# 3        5.25                      0.24                     0.25
# 4        5.60                      0.24                     0.25
# 5       38.90                      0.14                     0.17
# 6       30.40                      0.14                     0.17
# 7       26.90                      0.14                     0.17
# 8       25.65                      0.14                     0.17
# 9       24.70                      0.14                     0.17
# 10     480.00                      0.23                     0.23
# 11     552.10                      0.23                     0.23
# 12     525.60                      0.23                     0.23
# 13     569.38                      0.23                     0.23
# 14     560.68                      0.23                     0.23
# 15     466.10                      0.05                     0.13
# 16     684.50                      0.05                     0.13
# 17     695.47                      0.05                     0.13
# 18     754.62                      0.05                     0.13
# 19     640.78                      0.05                     0.13
# 20     858.00                      0.17                     0.18
# 21     741.00                      0.17                     0.18
# 22     824.00                      0.17                     0.18
# 23     798.42                      0.17                     0.18
# 24     818.32                      0.17                     0.18
# 25     245.70                      0.06                     0.13
# 26     241.20                      0.06                     0.13
# 27     239.03                      0.06                     0.14
# 28     298.77                      0.06                     0.14
# 29     264.42                      0.06                     0.14
# 30      71.80                      0.20                     0.20
# 31      73.80                      0.20                     0.20
# 32      74.80                      0.20                     0.20
# 33      74.30                      0.20                     0.20
# 34      73.80                      0.20                     0.20

# %%
reg.check_model(df=data_model_k_best_organic, y="fea_average_price", choose="select")
# Out:
#                    model_name  score_train_mean  score_test_mean  abs|score|  \
# 0            LinearRegression              0.09             0.09        0.01
# 1            LinearRegression              0.09             0.09        0.01
# 2            LinearRegression              0.09             0.09        0.01
# 3            LinearRegression              0.09             0.09        0.01
# 4            LinearRegression              0.09             0.09        0.01
# 5         KNeighborsRegressor              0.61             0.39        0.23
# 6         KNeighborsRegressor              0.61             0.40        0.21
# 7         KNeighborsRegressor              0.61             0.40        0.21
# 8         KNeighborsRegressor              0.60             0.40        0.20
# 9         KNeighborsRegressor              0.61             0.40        0.20
# 10                        SVR              0.19             0.17        0.02
# 11                        SVR              0.19             0.19        0.02
# 12                        SVR              0.19             0.19        0.01
# 13                        SVR              0.19             0.18        0.01
# 14                        SVR              0.19             0.18        0.02
# 15      RandomForestRegressor              0.95             0.67        0.28
# 16      RandomForestRegressor              0.95             0.66        0.29
# 17      RandomForestRegressor              0.95             0.65        0.30
# 18      RandomForestRegressor              0.95             0.64        0.31
# 19      RandomForestRegressor              0.95             0.64        0.31
# 20  GradientBoostingRegressor              0.54             0.48        0.06
# 21  GradientBoostingRegressor              0.55             0.48        0.07
# 22  GradientBoostingRegressor              0.54             0.48        0.06
# 23  GradientBoostingRegressor              0.55             0.48        0.06
# 24  GradientBoostingRegressor              0.55             0.48        0.06
# 25               XGBRegressor              0.91             0.62        0.29
# 26               XGBRegressor              0.91             0.61        0.30
# 27               XGBRegressor              0.91             0.62        0.29
# 28               XGBRegressor              0.91             0.62        0.29
# 29               XGBRegressor              0.91             0.62        0.30
# 30              LGBMRegressor              0.40             0.37        0.04
# 31              LGBMRegressor              0.40             0.37        0.03
# 32              LGBMRegressor              0.40             0.37        0.04
# 33              LGBMRegressor              0.40             0.37        0.03
# 34              LGBMRegressor              0.40             0.37        0.04
#
#     time_mean  mean_squared_error_train  mean_squared_error_test
# 0        7.00                      0.35                     0.35
# 1        7.50                      0.34                     0.35
# 2        6.67                      0.35                     0.35
# 3        6.50                      0.35                     0.35
# 4        6.20                      0.35                     0.35
# 5       22.90                      0.22                     0.29
# 6       20.90                      0.23                     0.29
# 7       20.23                      0.23                     0.29
# 8       20.40                      0.23                     0.28
# 9       21.10                      0.23                     0.28
# 10     542.90                      0.33                     0.33
# 11     520.95                      0.33                     0.33
# 12     563.17                      0.33                     0.33
# 13     594.00                      0.33                     0.33
# 14     595.16                      0.33                     0.33
# 15     176.40                      0.08                     0.21
# 16     124.25                      0.08                     0.21
# 17     132.80                      0.08                     0.21
# 18     263.02                      0.08                     0.22
# 19     311.24                      0.08                     0.22
# 20     787.20                      0.24                     0.27
# 21     781.75                      0.24                     0.27
# 22     821.53                      0.24                     0.26
# 23     774.47                      0.24                     0.26
# 24     624.94                      0.24                     0.26
# 25     590.40                      0.11                     0.22
# 26     556.45                      0.11                     0.22
# 27     473.17                      0.11                     0.22
# 28     385.12                      0.11                     0.22
# 29     335.80                      0.11                     0.22
# 30      84.80                      0.28                     0.29
# 31      86.30                      0.28                     0.29
# 32      85.80                      0.28                     0.29
# 33      86.30                      0.28                     0.29
# 34      85.40                      0.28                     0.29

# %% [markdown]
# ## B2. Model scaler - Check model - scaler vs type
# - conventional
# - organic

# %%
reg.check_model(df=data_model_k_best_conventional_scaler, y="fea_average_price", choose="select")
# Out:
#                    model_name  score_train_mean  score_test_mean  abs|score|  \
# 0            LinearRegression              0.13             0.13        0.00
# 1            LinearRegression              0.13             0.14        0.01
# 2            LinearRegression              0.13             0.13        0.01
# 3            LinearRegression              0.13             0.13        0.01
# 4            LinearRegression              0.13             0.13        0.01
# 5         KNeighborsRegressor              0.68             0.49        0.18
# 6         KNeighborsRegressor              0.68             0.49        0.19
# 7         KNeighborsRegressor              0.68             0.48        0.20
# 8         KNeighborsRegressor              0.68             0.49        0.19
# 9         KNeighborsRegressor              0.68             0.49        0.19
# 10                        SVR              0.20             0.19        0.01
# 11                        SVR              0.20             0.19        0.01
# 12                        SVR              0.20             0.19        0.01
# 13                        SVR              0.20             0.19        0.01
# 14                        SVR              0.20             0.19        0.01
# 15      RandomForestRegressor              0.97             0.77        0.20
# 16      RandomForestRegressor              0.97             0.76        0.20
# 17      RandomForestRegressor              0.97             0.77        0.20
# 18      RandomForestRegressor              0.97             0.77        0.20
# 19      RandomForestRegressor              0.97             0.76        0.20
# 20  GradientBoostingRegressor              0.59             0.56        0.03
# 21  GradientBoostingRegressor              0.59             0.55        0.04
# 22  GradientBoostingRegressor              0.59             0.55        0.04
# 23  GradientBoostingRegressor              0.59             0.55        0.04
# 24  GradientBoostingRegressor              0.59             0.55        0.04
# 25               XGBRegressor              0.94             0.73        0.21
# 26               XGBRegressor              0.94             0.73        0.21
# 27               XGBRegressor              0.95             0.73        0.22
# 28               XGBRegressor              0.95             0.73        0.21
# 29               XGBRegressor              0.95             0.73        0.22
# 30              LGBMRegressor              0.44             0.42        0.03
# 31              LGBMRegressor              0.45             0.40        0.04
# 32              LGBMRegressor              0.45             0.41        0.04
# 33              LGBMRegressor              0.45             0.41        0.04
# 34              LGBMRegressor              0.45             0.41        0.04
#
#     time_mean  mean_squared_error_train  mean_squared_error_test
# 0        5.00                      0.25                     0.24
# 1        5.50                      0.25                     0.24
# 2        6.33                      0.25                     0.24
# 3        5.75                      0.25                     0.24
# 4        5.40                      0.25                     0.24
# 5       20.90                      0.15                     0.19
# 6       19.90                      0.15                     0.19
# 7       20.57                      0.15                     0.19
# 8       21.90                      0.15                     0.19
# 9       21.50                      0.15                     0.19
# 10     473.10                      0.24                     0.24
# 11     485.55                      0.24                     0.24
# 12     539.73                      0.24                     0.24
# 13     565.30                      0.24                     0.24
# 14     628.34                      0.24                     0.24
# 15     223.80                      0.05                     0.13
# 16     606.50                      0.05                     0.13
# 17     638.33                      0.05                     0.13
# 18     614.30                      0.05                     0.13
# 19     666.26                      0.05                     0.13
# 20      76.00                      0.17                     0.17
# 21      73.90                      0.17                     0.18
# 22     159.43                      0.17                     0.18
# 23     346.48                      0.17                     0.18
# 24     423.30                      0.17                     0.18
# 25     728.80                      0.06                     0.14
# 26     516.90                      0.06                     0.14
# 27     431.13                      0.06                     0.14
# 28     397.98                      0.06                     0.14
# 29     483.12                      0.06                     0.14
# 30      84.80                      0.20                     0.20
# 31     114.70                      0.20                     0.20
# 32     103.73                      0.20                     0.20
# 33     118.95                      0.20                     0.20
# 34     117.50                      0.20                     0.20

# %%
reg.check_model(df=data_model_k_best_organic_scaler, y="fea_average_price", choose="select")
# Out:
#                    model_name  score_train_mean  score_test_mean  abs|score|  \
# 0            LinearRegression              0.09             0.09        0.00
# 1            LinearRegression              0.09             0.09        0.01
# 2            LinearRegression              0.09             0.08        0.01
# 3            LinearRegression              0.09             0.08        0.01
# 4            LinearRegression              0.09             0.08        0.01
# 5         KNeighborsRegressor              0.63             0.37        0.26
# 6         KNeighborsRegressor              0.62             0.40        0.22
# 7         KNeighborsRegressor              0.62             0.40        0.22
# 8         KNeighborsRegressor              0.62             0.39        0.23
# 9         KNeighborsRegressor              0.62             0.39        0.23
# 10                        SVR              0.20             0.19        0.01
# 11                        SVR              0.20             0.19        0.01
# 12                        SVR              0.20             0.19        0.01
# 13                        SVR              0.20             0.19        0.02
# 14                        SVR              0.20             0.19        0.02
# 15      RandomForestRegressor              0.95             0.67        0.29
# 16      RandomForestRegressor              0.95             0.65        0.30
# 17      RandomForestRegressor              0.95             0.66        0.29
# 18      RandomForestRegressor              0.95             0.66        0.30
# 19      RandomForestRegressor              0.95             0.66        0.29
# 20  GradientBoostingRegressor              0.54             0.49        0.06
# 21  GradientBoostingRegressor              0.54             0.49        0.06
# 22  GradientBoostingRegressor              0.54             0.48        0.06
# 23  GradientBoostingRegressor              0.54             0.49        0.06
# 24  GradientBoostingRegressor              0.54             0.49        0.05
# 25               XGBRegressor              0.91             0.62        0.29
# 26               XGBRegressor              0.91             0.62        0.29
# 27               XGBRegressor              0.91             0.63        0.28
# 28               XGBRegressor              0.91             0.63        0.28
# 29               XGBRegressor              0.91             0.62        0.29
# 30              LGBMRegressor              0.41             0.35        0.05
# 31              LGBMRegressor              0.41             0.36        0.05
# 32              LGBMRegressor              0.40             0.36        0.04
# 33              LGBMRegressor              0.40             0.37        0.04
# 34              LGBMRegressor              0.40             0.37        0.04
#
#     time_mean  mean_squared_error_train  mean_squared_error_test
# 0        7.00                      0.35                     0.35
# 1        6.00                      0.35                     0.35
# 2        5.33                      0.35                     0.35
# 3        4.75                      0.35                     0.35
# 4        4.40                      0.35                     0.35
# 5       17.00                      0.22                     0.28
# 6       19.95                      0.22                     0.28
# 7       23.60                      0.22                     0.28
# 8       25.17                      0.22                     0.28
# 9       24.32                      0.22                     0.28
# 10     810.40                      0.33                     0.32
# 11     734.10                      0.33                     0.32
# 12     717.90                      0.33                     0.32
# 13     717.17                      0.33                     0.32
# 14     681.12                      0.33                     0.32
# 15     514.50                      0.08                     0.21
# 16     568.90                      0.08                     0.22
# 17     459.17                      0.08                     0.21
# 18     385.50                      0.08                     0.21
# 19     417.56                      0.08                     0.21
# 20     705.40                      0.25                     0.26
# 21     821.20                      0.25                     0.26
# 22     663.90                      0.25                     0.26
# 23     553.20                      0.24                     0.26
# 24     610.58                      0.25                     0.26
# 25     262.60                      0.11                     0.23
# 26     201.75                      0.11                     0.22
# 27     175.17                      0.11                     0.22
# 28     157.15                      0.11                     0.22
# 29     199.80                      0.11                     0.22
# 30     100.80                      0.28                     0.29
# 31      96.05                      0.28                     0.29
# 32      90.97                      0.28                     0.29
# 33      86.67                      0.28                     0.29
# 34      84.70                      0.28                     0.29

# %% [markdown]
# #### Nhận xét:
# - Chung ta sẽ chọn model hình XGBRegressor hoặc RandomForestRegressor
# - Có hiện tưởng overfitting
# - Cần cải thiện thêm model

# %% [markdown]
# ## B2. Model - check model - lazy

# %%
reg.check_model_final_lazy(df=data_model_k_best_conventional, y='fea_average_price', choose='model')
# Out:
# 100%|██████████| 42/42 [00:36<00:00,  1.14it/s]
#                                Adjusted R-Squared  R-Squared  RMSE  Time Taken
# Model
# ExtraTreesRegressor                          0.77       0.77  0.13        2.55
# RandomForestRegressor                        0.74       0.75  0.13        5.80
# XGBRegressor                                 0.72       0.72  0.14        1.48
# BaggingRegressor                             0.71       0.71  0.14        0.68
# LGBMRegressor                                0.70       0.70  0.14        0.32
# HistGradientBoostingRegressor                0.70       0.70  0.14        1.00
# KNeighborsRegressor                          0.55       0.55  0.18        0.13
# GradientBoostingRegressor                    0.53       0.53  0.18        2.25
# DecisionTreeRegressor                        0.43       0.44  0.20        0.09
# ExtraTreeRegressor                           0.37       0.37  0.21        0.04
# MLPRegressor                                 0.36       0.36  0.21        4.38
# NuSVR                                        0.34       0.35  0.21        2.45
# SVR                                          0.34       0.34  0.21        1.92
# AdaBoostRegressor                            0.28       0.29  0.22        1.03
# RidgeCV                                      0.12       0.12  0.25        0.02
# BayesianRidge                                0.12       0.12  0.25        0.02
# ElasticNetCV                                 0.12       0.12  0.25        0.15
# LassoCV                                      0.12       0.12  0.25        0.24
# Ridge                                        0.12       0.12  0.25        0.02
# LassoLarsCV                                  0.12       0.12  0.25        0.05
# LassoLarsIC                                  0.12       0.12  0.25        0.02
# LarsCV                                       0.12       0.12  0.25        0.07
# Lars                                         0.12       0.12  0.25        0.02
# SGDRegressor                                 0.11       0.12  0.25        0.03
# OrthogonalMatchingPursuitCV                  0.11       0.12  0.25        0.03
# HuberRegressor                               0.11       0.12  0.25        0.07
# TransformedTargetRegressor                   0.11       0.12  0.25        0.02
# LinearRegression                             0.11       0.12  0.25        0.02
# LinearSVR                                    0.10       0.11  0.25        0.52
# PoissonRegressor                             0.05       0.06  0.25        0.02
# GammaRegressor                               0.05       0.05  0.25        0.03
# TweedieRegressor                             0.05       0.05  0.25        0.02
# GeneralizedLinearRegressor                   0.05       0.05  0.25        0.03
# OrthogonalMatchingPursuit                    0.04       0.05  0.26        0.02
# ElasticNet                                  -0.00      -0.00  0.26        0.02
# DummyRegressor                              -0.00      -0.00  0.26        0.02
# Lasso                                       -0.00      -0.00  0.26        0.04
# LassoLars                                   -0.00      -0.00  0.26        0.03
# RANSACRegressor                             -1.12      -1.11  0.38        0.11
# PassiveAggressiveRegressor                 -11.40     -11.35  0.92        0.02
# KernelRidge                                -19.30     -19.22  1.18        3.42
# GaussianProcessRegressor                -56740.67  -56512.62 62.32        7.48

# %%
reg.check_model_final_lazy(df=data_model_k_best_conventional, y='fea_average_price', choose='predictions')
# Out:
# 100%|██████████| 42/42 [00:40<00:00,  1.04it/s]
#                                Adjusted R-Squared  R-Squared  RMSE  Time Taken
# Model
# ExtraTreesRegressor                          0.77       0.77  0.13        2.63
# RandomForestRegressor                        0.74       0.75  0.13        6.84
# XGBRegressor                                 0.72       0.72  0.14        2.30
# BaggingRegressor                             0.71       0.71  0.14        0.64
# LGBMRegressor                                0.70       0.70  0.14        0.41
# HistGradientBoostingRegressor                0.70       0.70  0.14        1.02
# KNeighborsRegressor                          0.55       0.55  0.18        0.14
# GradientBoostingRegressor                    0.53       0.53  0.18        2.20
# DecisionTreeRegressor                        0.43       0.44  0.20        0.10
# ExtraTreeRegressor                           0.37       0.37  0.21        0.04
# MLPRegressor                                 0.36       0.36  0.21        4.77
# NuSVR                                        0.34       0.35  0.21        3.06
# SVR                                          0.34       0.34  0.21        2.38
# AdaBoostRegressor                            0.28       0.29  0.22        0.85
# RidgeCV                                      0.12       0.12  0.25        0.03
# BayesianRidge                                0.12       0.12  0.25        0.02
# ElasticNetCV                                 0.12       0.12  0.25        0.21
# LassoCV                                      0.12       0.12  0.25        0.22
# Ridge                                        0.12       0.12  0.25        0.03
# LassoLarsCV                                  0.12       0.12  0.25        0.05
# LassoLarsIC                                  0.12       0.12  0.25        0.03
# LarsCV                                       0.12       0.12  0.25        0.06
# Lars                                         0.12       0.12  0.25        0.05
# SGDRegressor                                 0.11       0.12  0.25        0.03
# OrthogonalMatchingPursuitCV                  0.11       0.12  0.25        0.04
# HuberRegressor                               0.11       0.12  0.25        0.06
# TransformedTargetRegressor                   0.11       0.12  0.25        0.03
# LinearRegression                             0.11       0.12  0.25        0.02
# LinearSVR                                    0.10       0.11  0.25        0.53
# PoissonRegressor                             0.05       0.06  0.25        0.04
# GammaRegressor                               0.05       0.05  0.25        0.03
# TweedieRegressor                             0.05       0.05  0.25        0.03
# GeneralizedLinearRegressor                   0.05       0.05  0.25        0.02
# OrthogonalMatchingPursuit                    0.04       0.05  0.26        0.02
# ElasticNet                                  -0.00      -0.00  0.26        0.02
# DummyRegressor                              -0.00      -0.00  0.26        0.02
# Lasso                                       -0.00      -0.00  0.26        0.03
# LassoLars                                   -0.00      -0.00  0.26        0.02
# RANSACRegressor                             -1.12      -1.11  0.38        0.20
# PassiveAggressiveRegressor                 -11.40     -11.35  0.92        0.03
# KernelRidge                                -19.30     -19.22  1.18        3.70
# GaussianProcessRegressor                -56740.67  -56512.62 62.32        7.59

# %% [markdown]
# ## Nhận xét:
# - ExtraTreesRegressor: model và predictions đều thực hiện 88%
# - RandomForestRegressor: model và predictions đều thực hiện 86%
